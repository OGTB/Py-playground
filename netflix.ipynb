# %% [markdown]
# <a href="https://colab.research.google.com/github/OGTB/Py-playground/blob/master/netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime

# %%
df.shape
# Out:
# (8807, 12)

# %%
df = pd.read_csv('/content/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
for col in df.columns:
  print(col)
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# rating
# duration
# listed_in
# description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['release_year'].plot(kind='hist', bins=20, title='release_year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['release_year'].plot(kind='line', figsize=(8, 4), title='release_year')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Count the number of Movies vs TV Shows

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# Find the most common rating for movies and TV shows

# %%
df['rating'].value_counts().sort_values(ascending=False).head(1)
# Out:
# rating
# TV-MA    3207
# Name: count, dtype: int64

# %% [markdown]
# List all movies released in a specific year

# %%
movies = df[df['type'] == 'Movie']

# %%
movies['release_year'].value_counts()
# Out:
# release_year
# 2017    767
# 2018    767
# 2016    658
# 2019    633
# 2020    517
#        ...
# 1959      1
# 1963      1
# 1966      1
# 1946      1
# 1947      1
# Name: count, Length: 73, dtype: int64

# %% [markdown]
# Find the top 5 countries with the most content on Netflix

# %%
df['country'].value_counts().head()
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Name: count, dtype: int64

# %% [markdown]
# Identify the longest movie

# %%
movie = df[df['type'] == 'Movie']
movie["duration"].str.split(" ", expand = True)[0].dropna().astype(int).sort_values(ascending=False).head(1)
# Out:
# 4253    312
# Name: 0, dtype: int64

# %%
df['title'][df['duration'] == "312 min"]
# Out:
# 4253    Black Mirror: Bandersnatch
# Name: title, dtype: object

# %% [markdown]
# Find content added in the last 5 years

# %%
df[df["release_year"] >= datetime.datetime.now().year -5]
# Out:
#      show_id     type                                      title  \
# 0         s1    Movie                       Dick Johnson Is Dead
# 1         s2  TV Show                              Blood & Water
# 2         s3  TV Show                                  Ganglands
# 3         s4  TV Show                      Jailbirds New Orleans
# 4         s5  TV Show                               Kota Factory
# ...      ...      ...                                        ...
# 7594   s7595    Movie         Norm of the North: Family Vacation
# 8099   s8100    Movie                                Straight Up
# 8125   s8126  TV Show                                Super Wings
# 8132   s8133  TV Show  Surviving R. Kelly Part II: The Reckoning
# 8437   s8438  TV Show                     The Netflix Afterparty
#
#              director                                               cast  \
# 0     Kirsten Johnson                                                NaN
# ...

# %% [markdown]
# Find all the movies/TV shows by director 'Rajiv Chilaka'!

# %%
df['title'][df['director'] == "Rajiv Chilaka"]
# Out:
# 406                          Chhota Bheem - Neeli Pahaadi
# 407                                 Chhota Bheem & Ganesh
# 408                    Chhota Bheem & Krishna: Mayanagari
# 409     Chhota Bheem & Krishna: Pataliputra- City of t...
# 410                    Chhota Bheem And The Broken Amulet
# 411                Chhota Bheem And The Crown of Valhalla
# 412                  Chhota Bheem and the Incan Adventure
# 413                   Chhota Bheem and The ShiNobi Secret
# 414                              Chhota Bheem Aur Hanuman
# 415                              Chhota Bheem aur Krishna
# 416                   Chhota Bheem aur Krishna vs Zimbara
# 419                         Chhota Bheem: Bheem vs Aliens
# 420                  Chhota Bheem: Dholakpur to Kathmandu
# 422                        Chhota Bheem: Journey to Petra
# 423                       Chhota Bheem: Master of Shaolin
# 424                     Chhota Bheem: The Rise of Kirmada
# ...

# %% [markdown]
# List all TV shows with more than 5 seasons

# %%
seasoncounts = df['duration'][df['type'] == 'TV Show'].dropna().str.split(" ", expand = True)[0].astype(int)

# %%
print(f"Tv shows with more than 5 seasons:  {seasoncounts[seasoncounts >= 5].count()}")
# Out:
# Tv shows with more than 5 seasons:  164

# %% [markdown]
# Count the number of content items in each genre

# %%
print(df["listed_in"].value_counts())
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
#                                                    ...
# Action & Adventure, Cult Movies                       1
# Action & Adventure, Comedies, Music & Musicals        1
# Classic Movies, Horror Movies, Thrillers              1
# Children & Family Movies, Classic Movies, Dramas      1
# Cult Movies, Dramas, Thrillers                        1
# Name: count, Length: 514, dtype: int64

# %% [markdown]
# Find each year and the average numbers of content release in India on netflix

# %%
India = df[df['country'] == 'India']

# %%
pd.pivot_table(India, index = 'release_year', aggfunc='count',fill_value = 0)
# Out:
#               cast  country  date_added  description  director  duration  \
# release_year
# 1959             1        1           1            1         1         1
# 1962             1        1           1            1         1         1
# 1964             1        1           1            1         1         1
# 1966             1        1           1            1         1         1
# 1969             1        1           1            1         1         1
# 1971             2        2           2            2         2         2
# 1972             2        2           2            2         2         2
# 1973             2        2           2            2         2         2
# 1974             2        2           2            2         2         2
# 1975             2        2           2            2         2         2
# 1976             2        2           2            2         1         2
# 1977             2        2           2            2         2         2
# ...
